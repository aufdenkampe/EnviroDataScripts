# %% [markdown]
# CZOData Example 1: Read and plot CZO_DisplayFile_v1 with Pandas.
#     Read from a "CZO Display File v1", convert to Pandas DataFrame and plot time series.
#     Writen by Anthony Aufdenkampe, Friday Dec. 13, 2013.

# %%
# Import all required Python libraries and modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a list of file paths for the CZO Display Files (v1) to read
#   Examples here available at http://czo.stroudcenter.org/data/ or http://criticalzone.org/christina/data/

file_paths = ['/Users/anthony/AnthonyWork/PythonScripts/EnviroDataScripts/CZODisplayParsePlot/DemoData/CRB_WCC_STAGEFLOW_2009.csv', 
              '/Users/anthony/AnthonyWork/PythonScripts/EnviroDataScripts/CZODisplayParsePlot/DemoData/CRB_WCC_STAGEFLOW_2010.csv'
              ]

# %%
# A For loop that reads each file using the Pandas "read_csv" function, 
#   then appends the resulting DataFrame object to a list called "data_frames".

data_frames = []
for file_path in file_paths:
    df = pd.read_csv(file_path, header=0, skipinitialspace=True, skiprows=[1], index_col=0, na_values=[-9999], parse_dates=True)
    data_frames.append(df)

# %%
# Concatenate all the DataFrames in the "ata_frames" list into a single DataFrame
df = pd.concat(data_frames)

# %%
df
# Out:
#                     Gage Height (ft) from Continuous record  Gage Height (ft)  \
# Date Time (EST)
# 2009-01-01 00:10:00                                   3.082               NaN
# 2009-01-01 00:25:00                                   3.083               NaN
# 2009-01-01 00:40:00                                   3.083               NaN
# 2009-01-01 00:55:00                                   3.082               NaN
# 2009-01-01 01:10:00                                   3.081               NaN
# 2009-01-01 01:25:00                                   3.082               NaN
# 2009-01-01 01:40:00                                   3.081               NaN
# 2009-01-01 01:55:00                                   3.081               NaN
# 2009-01-01 02:10:00                                   3.082               NaN
# 2009-01-01 02:25:00                                   3.081               NaN
# 2009-01-01 02:40:00                                   3.082               NaN
# 2009-01-01 02:55:00                                   3.082               NaN
# 2009-01-01 03:10:00                                   3.082               NaN
# 2009-01-01 03:25:00                                   3.081               NaN
# 2009-01-01 03:40:00                                   3.081               NaN
# 2009-01-01 03:55:00                                   3.082               NaN
# 2009-01-01 04:10:00                                   3.082               NaN
# 2009-01-01 04:25:00                                   3.082               NaN
# 2009-01-01 04:40:00                                   3.081               NaN
# 2009-01-01 04:55:00                                   3.081               NaN
# 2009-01-01 05:10:00                                   3.082               NaN
# 2009-01-01 05:25:00                                   3.082               NaN
# 2009-01-01 05:40:00                                   3.082               NaN
# 2009-01-01 05:55:00                                   3.082               NaN
# 2009-01-01 06:10:00                                   3.084               NaN
# 2009-01-01 06:25:00                                   3.083               NaN
# 2009-01-01 06:40:00                                   3.084               NaN
# 2009-01-01 06:55:00                                   3.083               NaN
# 2009-01-01 07:10:00                                   3.083               NaN
# 2009-01-01 07:25:00                                   3.081               NaN
# ...                                                     ...               ...
# 2010-12-31 16:30:00                                    3.01               NaN
# 2010-12-31 16:45:00                                   3.012               NaN
# 2010-12-31 17:00:00                                   3.013               NaN
# 2010-12-31 17:15:00                                   3.014               NaN
# 2010-12-31 17:30:00                                   3.016               NaN
# 2010-12-31 17:45:00                                   3.018               NaN
# 2010-12-31 18:00:00                                   3.018               NaN
# 2010-12-31 18:15:00                                   3.021               NaN
# 2010-12-31 18:30:00                                    3.02               NaN
# 2010-12-31 18:45:00                                   3.022               NaN
# 2010-12-31 19:00:00                                   3.023               NaN
# 2010-12-31 19:15:00                                   3.023               NaN
# 2010-12-31 19:30:00                                   3.024               NaN
# 2010-12-31 19:45:00                                   3.024               NaN
# 2010-12-31 20:00:00                                   3.025               NaN
# 2010-12-31 20:15:00                                   3.025               NaN
# 2010-12-31 20:30:00                                   3.026               NaN
# 2010-12-31 20:45:00                                   3.027               NaN
# 2010-12-31 21:00:00                                   3.025               NaN
# 2010-12-31 21:15:00                                   3.026               NaN
# 2010-12-31 21:30:00                                   3.027               NaN
# 2010-12-31 21:45:00                                   3.026               NaN
# 2010-12-31 22:00:00                                   3.026               NaN
# 2010-12-31 22:15:00                                   3.025               NaN
# 2010-12-31 22:30:00                                   3.025               NaN
# 2010-12-31 22:45:00                                   3.025               NaN
# 2010-12-31 23:00:00                                   3.025               NaN
# 2010-12-31 23:15:00                                   3.026               NaN
# 2010-12-31 23:30:00                                   3.025               NaN
# 2010-12-31 23:45:00                                   3.024               NaN
#
#                     Discharge (cfs) from Continuous record  Discharge (cfs)
# Date Time (EST)
# 2009-01-01 00:10:00                                   2.15              NaN
# 2009-01-01 00:25:00                                   2.16              NaN
# 2009-01-01 00:40:00                                   2.16              NaN
# 2009-01-01 00:55:00                                   2.15              NaN
# 2009-01-01 01:10:00                                   2.13              NaN
# 2009-01-01 01:25:00                                   2.15              NaN
# 2009-01-01 01:40:00                                   2.14              NaN
# 2009-01-01 01:55:00                                   2.14              NaN
# 2009-01-01 02:10:00                                   2.14              NaN
# 2009-01-01 02:25:00                                   2.14              NaN
# 2009-01-01 02:40:00                                   2.14              NaN
# 2009-01-01 02:55:00                                   2.15              NaN
# 2009-01-01 03:10:00                                   2.14              NaN
# 2009-01-01 03:25:00                                   2.13              NaN
# 2009-01-01 03:40:00                                   2.13              NaN
# 2009-01-01 03:55:00                                   2.15              NaN
# 2009-01-01 04:10:00                                   2.14              NaN
# 2009-01-01 04:25:00                                   2.15              NaN
# 2009-01-01 04:40:00                                   2.13              NaN
# 2009-01-01 04:55:00                                   2.14              NaN
# 2009-01-01 05:10:00                                   2.15              NaN
# 2009-01-01 05:25:00                                   2.14              NaN
# 2009-01-01 05:40:00                                   2.15              NaN
# 2009-01-01 05:55:00                                   2.15              NaN
# 2009-01-01 06:10:00                                   2.17              NaN
# 2009-01-01 06:25:00                                   2.16              NaN
# 2009-01-01 06:40:00                                   2.17              NaN
# 2009-01-01 06:55:00                                   2.16              NaN
# 2009-01-01 07:10:00                                   2.16              NaN
# 2009-01-01 07:25:00                                   2.14              NaN
# ...                                                    ...              ...
# 2010-12-31 16:30:00                                   2.53              NaN
# 2010-12-31 16:45:00                                   2.57              NaN
# 2010-12-31 17:00:00                                   2.57              NaN
# 2010-12-31 17:15:00                                   2.59              NaN
# 2010-12-31 17:30:00                                   2.62              NaN
# 2010-12-31 17:45:00                                   2.63              NaN
# 2010-12-31 18:00:00                                   2.64              NaN
# 2010-12-31 18:15:00                                   2.67              NaN
# 2010-12-31 18:30:00                                   2.67              NaN
# 2010-12-31 18:45:00                                    2.7              NaN
# 2010-12-31 19:00:00                                    2.7              NaN
# 2010-12-31 19:15:00                                    2.7              NaN
# 2010-12-31 19:30:00                                   2.72              NaN
# 2010-12-31 19:45:00                                   2.72              NaN
# 2010-12-31 20:00:00                                   2.73              NaN
# 2010-12-31 20:15:00                                   2.73              NaN
# 2010-12-31 20:30:00                                   2.74              NaN
# 2010-12-31 20:45:00                                   2.76              NaN
# 2010-12-31 21:00:00                                   2.73              NaN
# 2010-12-31 21:15:00                                   2.74              NaN
# 2010-12-31 21:30:00                                   2.76              NaN
# 2010-12-31 21:45:00                                   2.75              NaN
# 2010-12-31 22:00:00                                   2.75              NaN
# 2010-12-31 22:15:00                                   2.73              NaN
# 2010-12-31 22:30:00                                   2.73              NaN
# 2010-12-31 22:45:00                                   2.73              NaN
# 2010-12-31 23:00:00                                   2.73              NaN
# 2010-12-31 23:15:00                                   2.74              NaN
# 2010-12-31 23:30:00                                   2.73              NaN
# 2010-12-31 23:45:00                                   2.72              NaN
#
# [70058 rows x 4 columns]

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-01-01 00:10:00, ..., 2010-12-31 23:45:00]
# Length: 70058, Freq: None, Timezone: None

# %%
df.index = df.index.tz_localize('EST')

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2009-01-01 00:10:00-05:00, ..., 2010-12-31 23:45:00-05:00]
# Length: 70058, Freq: None, Timezone: EST

# %%
df.dtypes
# Out:
# Gage Height (ft) from Continuous record     object
# Gage Height (ft)                           float64
# Discharge (cfs) from Continuous record      object
# Discharge (cfs)                            float64
# dtype: object

# %%
df = df.convert_objects(convert_numeric='force')

# %%
df.dtypes
# Out:
# Gage Height (ft) from Continuous record    float64
# Gage Height (ft)                           float64
# Discharge (cfs) from Continuous record     float64
# Discharge (cfs)                            float64
# dtype: object

# %%
df.head(n=5)
# Out:
#                            Gage Height (ft) from Continuous record  \
# Date Time (EST)
# 2009-01-01 00:10:00-05:00                                    3.082
# 2009-01-01 00:25:00-05:00                                    3.083
# 2009-01-01 00:40:00-05:00                                    3.083
# 2009-01-01 00:55:00-05:00                                    3.082
# 2009-01-01 01:10:00-05:00                                    3.081
#
#                            Gage Height (ft)  \
# Date Time (EST)
# 2009-01-01 00:10:00-05:00               NaN
# 2009-01-01 00:25:00-05:00               NaN
# 2009-01-01 00:40:00-05:00               NaN
# 2009-01-01 00:55:00-05:00               NaN
# 2009-01-01 01:10:00-05:00               NaN
#
#                            Discharge (cfs) from Continuous record  \
# Date Time (EST)
# 2009-01-01 00:10:00-05:00                                    2.15
# 2009-01-01 00:25:00-05:00                                    2.16
# 2009-01-01 00:40:00-05:00                                    2.16
# 2009-01-01 00:55:00-05:00                                    2.15
# 2009-01-01 01:10:00-05:00                                    2.13
#
#                            Discharge (cfs)
# Date Time (EST)
# 2009-01-01 00:10:00-05:00              NaN
# 2009-01-01 00:25:00-05:00              NaN
# 2009-01-01 00:40:00-05:00              NaN
# 2009-01-01 00:55:00-05:00              NaN
# 2009-01-01 01:10:00-05:00              NaN

# %%
df.columns
# Out:
# Index([u'Gage Height (ft) from Continuous record', u'Gage Height (ft)', u'Discharge (cfs) from Continuous record', u'Discharge (cfs)'], dtype=object)

# %%
# %matplotlib
# Out:
# Using matplotlib backend: MacOSX

# %%
plt.figure(1)

# %%
ax = df[u'Discharge (cfs) from Continuous record'].plot(title=file_path, style='b', logy=True, ylim=(1,1000), legend=True)
ax.set_ylabel(u'Discharge (cfs) from Continuous record', color='b')

# %%
ax = df[u'Gage Height (ft) from Continuous record'].plot(secondary_y=True, style='g', legend=True)
ax.right_ax.set_ylabel(u'Gage Height (ft) from Continuous record', color='g')
